# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv = '/Users/alchemist/Documents/Python_Library/TS_Bank-of-England_Forcasting/data/Bank of England  Database.csv'
a = pd.read_csv(csv)
data = pd.read_csv(csv,
                   engine='pyarrow',
                   dtype_backend='pyarrow', 
                   parse_dates=True,
                   names=['Date', 'GBPUSD', 'USDGBP'])

df = pd.DataFrame(data)
df = df.iloc[:, 0:2]
df = df[1:]
df
# Out:
#            Date  GBPUSD
# 1     12 Jan 26  0.7421
# 2     09 Jan 26  0.7452
# 3     08 Jan 26   0.744
# 4     07 Jan 26  0.7418
# 5     06 Jan 26  0.7404
# ...         ...     ...
# 2529  08 Jan 16  0.6878
# 2530  07 Jan 16  0.6865
# 2531  06 Jan 16  0.6846
# 2532  05 Jan 16  0.6827
# 2533  04 Jan 16  0.6808
#
# [2533 rows x 2 columns]

# %%
a
# Out:
#            Date  \
# 0     12 Jan 26
# 1     09 Jan 26
# 2     08 Jan 26
# 3     07 Jan 26
# 4     06 Jan 26
# ...         ...
# 2528  08 Jan 16
# 2529  07 Jan 16
# 2530  06 Jan 16
# 2531  05 Jan 16
# 2532  04 Jan 16
#
#       Spot exchange rate, Sterling into US$              [a] [a] [a]             XUDLGBD  \
# 0                                                0.7421
# 1                                                0.7452
# 2                                                0.7440
# 3                                                0.7418
# 4                                                0.7404
# ...                                                 ...
# 2528                                             0.6878
# 2529                                             0.6865
# 2530                                             0.6846
# 2531                                             0.6827
# 2532                                             0.6808
#
# ...

# %%
(a
 .dtypes
 .describe()
 .info())
# Out:
# <class 'pandas.core.series.Series'>
# Index: 4 entries, count to freq
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 4 non-null      object
# dtypes: object(1)
# memory usage: 64.0+ bytes

# %%
a['Date'] = pd.to_datetime(a['Date'])
a
# Out:
#            Date  \
# 0    2026-01-12
# 1    2026-01-09
# 2    2026-01-08
# 3    2026-01-07
# 4    2026-01-06
# ...         ...
# 2528 2016-01-08
# 2529 2016-01-07
# 2530 2016-01-06
# 2531 2016-01-05
# 2532 2016-01-04
#
#       Spot exchange rate, Sterling into US$              [a] [a] [a]             XUDLGBD  \
# 0                                                0.7421
# 1                                                0.7452
# 2                                                0.7440
# 3                                                0.7418
# 4                                                0.7404
# ...                                                 ...
# 2528                                             0.6878
# 2529                                             0.6865
# 2530                                             0.6846
# 2531                                             0.6827
# 2532                                             0.6808
#
# ...

# %%
a = a.sort_values(by='Date')

# %%
a.head(10)
# Out:
#            Date  \
# 2532 2016-01-04
# 2531 2016-01-05
# 2530 2016-01-06
# 2529 2016-01-07
# 2528 2016-01-08
# 2527 2016-01-11
# 2526 2016-01-12
# 2525 2016-01-13
# 2524 2016-01-14
# 2523 2016-01-15
#
#       Spot exchange rate, Sterling into US$              [a] [a] [a]             XUDLGBD  \
# 2532                                             0.6808
# 2531                                             0.6827
# 2530                                             0.6846
# 2529                                             0.6865
# 2528                                             0.6878
# 2527                                             0.6882
# 2526                                             0.6961
# 2525                                             0.6925
# 2524                                             0.6948
# 2523                                             0.6990
#
#       Spot exchange rate, US $ into Sterling              [a] [a] [a]             XUDLUSS
# ...

# %%
b = a.iloc[:,0:2]

x = a['Date']
y = a['Spot exchange rate, Sterling into US$ [a] [a] [a] XUDLGBD']
plt.plot(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Spot exchange rate, Sterling into US$ [a] [a] [a] XUDLGBD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.dtypes
# Out:
# Date      string[pyarrow]
# GBPUSD    string[pyarrow]
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# /var/folders/sq/kdhn9tfx7tb_cvt5gjkm7wlh0000gn/T/ipykernel_30220/2394721818.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df['GBPUSD'] = pd.to_numeric(df['GBPUSD'])

# %%
df['GBPUSD'].is
# Out:
# Date      string[pyarrow]
# GBPUSD    double[pyarrow]
# dtype: object

# %%
plot = sns.lineplot(dashes=df, x='Date', y='GBPUSD')
plt.ylabel('GBPUSD')
plt.xlabel('Date')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 plot = sns.lineplot(dashes=df, x='Date', y='GBPUSD')
#       2 plt.ylabel('GBPUSD')
#       3 plt.xlabel('Date')
#
# File /opt/anaconda3/lib/python3.13/site-packages/seaborn/relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)
#     481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
# ...

# %%
GB = df['GBPUSD']

GB.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[146], line 3
#       1 GB = df['GBPUSD']
# ----> 3 GB.plot()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:499, in MPLPlot.generate(self)
#     497 @final
# ...
